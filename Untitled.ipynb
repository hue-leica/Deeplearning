# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x1=[1000,10000,50000]
y1=[178,1697,7878]
#x2=[1000,10000,50000]
#y2=[239,2637,10860]
plt.plot(x1,y1, label = 'patricia')
#plt.plot(x2,y2,label = 'maxb=100')
plt.legend()
plt.xlabel('Size of N')
plt.ylabel('Running time')
plt.show()
